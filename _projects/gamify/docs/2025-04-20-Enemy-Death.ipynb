# %% [markdown]
# ---
# layout: post
# title: Gamify Exploration
# description: Enemy Death, and Collision Graphics
# permalink: /gamify
# hide: true
# toc: false
# author: Sri Rohit Varma Datla
# ---
